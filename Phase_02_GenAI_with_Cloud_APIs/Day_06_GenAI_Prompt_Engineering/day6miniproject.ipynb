# %%
# !pip install langchain langchain-groq langchain-community langchain-core --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 24.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %%
import os
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
GROQ_API_KEY = os.getenv("GROQ_API_KEY")
llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)
prompt = PromptTemplate(
    input_variables=["problem"],
    template="""
You are an expert competitive programmer.

Problem:
{problem}

Use Tree of Thoughts reasoning.

Step 1:
Generate 4 different approaches to solve the problem.

For each approach provide:
- Idea
- Python Code
- Time Complexity
- Space Complexity

Step 2:
Compare all 4 approaches.

Step 3:
Rank them from Best to Worst.

Step 4:
Select the optimal solution based on:
- Lowest Time Complexity
- Lowest Space Complexity
- Readability
- Scalability

Final Output Format:

APPROACH 1
Idea:
Code:
Time Complexity:
Space Complexity:

APPROACH 2
...

APPROACH 3
...

APPROACH 4
...

COMPARISON TABLE

BEST SOLUTION

OPTIMAL CODE
"""
)

parser = StrOutputParser()

chain = prompt | llm | parser

response = chain.invoke({
    "problem": """
Given an array nums and an integer target,
return indices of the two numbers such that they add up to target.

Example:
nums = [2,7,11,15]
target = 9

Output: [0,1]
"""
})

print(response)
# Out:
# ### APPROACH 1
# Idea: Brute Force Approach - Use two nested loops to check every pair of numbers in the array.
# Code:
# ```python
# def two_sum(nums, target):
#     for i in range(len(nums)):
#         for j in range(i + 1, len(nums)):
#             if nums[i] + nums[j] == target:
#                 return [i, j]
# ```
# Time Complexity: O(n^2)
# Space Complexity: O(1)
#
# ### APPROACH 2
# Idea: Hash Table Approach - Use a dictionary to store the numbers we've seen so far and their indices.
# Code:
# ```python
# def two_sum(nums, target):
#     num_dict = {}
#     for i, num in enumerate(nums):
#         if target - num in num_dict:
#             return [num_dict[target - num], i]
#         num_dict[num] = i
# ```
# Time Complexity: O(n)
# Space Complexity: O(n)
#
# ### APPROACH 3
# Idea: Sorting Approach - Sort the array and use two pointers to find the pair of numbers.
# Code:
# ```python
# def two_sum(nums, target):
#     sorted_nums = sorted(enumerate(nums), key=lambda x: x[1])
#     left, right = 0, len(nums) - 1
#     while left < right:
#         if sorted_nums[left][1] + sorted_nums[right][1] == target:
#             return [sorted_nums[left][0], sorted_nums[right][0]]
#         elif sorted_nums[left][1] + sorted_nums[right][1] < target:
#             left += 1
#         else:
#             right -= 1
# ```
# Time Complexity: O(n log n)
# Space Complexity: O(n)
#
# ### APPROACH 4
# Idea: Binary Search Approach - Use binary search to find the pair of numbers.
# Code:
# ```python
# def two_sum(nums, target):
#     for i in range(len(nums)):
#         left, right = i + 1, len(nums) - 1
#         while left <= right:
#             mid = (left + right) // 2
#             if nums[mid] == target - nums[i]:
#                 return [i, mid]
#             elif nums[mid] < target - nums[i]:
#                 left = mid + 1
#             else:
#                 right = mid - 1
# ```
# Time Complexity: O(n log n)
# Space Complexity: O(1)
#
# ### COMPARISON TABLE
# | Approach | Time Complexity | Space Complexity |
# | --- | --- | --- |
# | 1 | O(n^2) | O(1) |
# | 2 | O(n) | O(n) |
# | 3 | O(n log n) | O(n) |
# | 4 | O(n log n) | O(1) |
#
# ### BEST SOLUTION
# The best solution is **APPROACH 2** because it has the lowest time complexity (O(n)) and is also relatively scalable and readable.
#
# ### OPTIMAL CODE
# ```python
# def two_sum(nums, target):
#     num_dict = {}
#     for i, num in enumerate(nums):
#         if target - num in num_dict:
#             return [num_dict[target - num], i]
#         num_dict[num] = i
# ```
# This code is optimal because it uses a hash table to store the numbers we've seen so far and their indices, allowing us to find the pair of numbers in O(n) time complexity. It also has a reasonable space complexity of O(n) and is relatively easy to read and understand.
